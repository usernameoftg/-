# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Акбар, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# # Проект: Статистический анализ данных
#
# Вы аналитик популярного сервиса аренды самокатов GoFast. Вам передали данные о некоторых пользователях из нескольких городов, а также об их поездках. Проанализируйте данные и проверьте некоторые гипотезы, которые могут помочь бизнесу вырасти.
#
# Чтобы совершать поездки по городу, пользователи сервиса GoFast пользуются мобильным приложением. Сервисом можно пользоваться:
#
#
#
# без подписки
# - абонентская плата отсутствует;
# - стоимость одной минуты поездки — 8 рублей;
# - стоимость старта (начала поездки) — 50 рублей;
#
# с подпиской Ultra
# - абонентская плата — 199 рублей в месяц;
# - стоимость одной минуты поездки — 6 рублей;
# - стоимость старта — бесплатно.
#
#
# #### Цель исследования
#
# Продакт-менеджеры сервиса хотят увеличить количество пользователей с подпиской. Для этого они будут проводить различные акции, но сначала нужно выяснить несколько важных моментов.
#
# #### Ход исследования
#
#
# * Важно понять, тратят ли пользователи с подпиской больше времени на поездки? Если да, то пользователи с подпиской могут быть «выгоднее» для компании. Проверьте гипотезу. Используйте исходные данные о продолжительности каждой сессии — отдельно для подписчиков и тех, у кого нет подписки.
#
# * Расстояние одной поездки в 3130 метров — оптимальное с точки зрения износа самоката. Можно ли сказать, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров? Проверьте гипотезу и сделайте выводы.
#
# * Проверьте гипотезу о том, будет ли помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки. Сделайте вывод.
#
# * Представьте такую ситуацию: техническая команда сервиса обновила сервера, с которыми взаимодействует мобильное приложение. Она надеется, что из-за этого количество обращений в техподдержку значимо снизилось. Некоторый файл содержит для каждого пользователя данные о количестве обращений до обновления и после него. Какой тест вам понадобился бы для проверки этой гипотезы?
#
# Исследование пройдет в 6 этапов:
# * Шаг 1. Загрузка данных
# * Шаг 2. Предобработка данных
# * Шаг 3. Исследовательский анализ данных
# * Шаг 4. Объединение данных
# * Шаг 5. Подсчёт выручки
# * Шаг 6. Проверка гипотез

# %% [markdown]
# "# Статистический анализ данных\n",
#         "Вы аналитик популярного сервиса аренды самокатов GoFast. Вам передали данные о некоторых пользователях из нескольких городов, а также об их поездках. Проанализируйте данные и проверьте некоторые гипотезы, которые могут помочь бизнесу вырасти.\n",
#         "Чтобвы совершать поездки по городу, пользователи сервиса GoFast пользуются мобильным приложением. Сервисом можно пользоваться:\n",
#         "\n",
#         "без подписки\n",
#         "* абонентская плата отсутствует;\n",
#         "* стоимость одной минуты поездки — 8 рублей;\n",
#         "* стоимость старта (начала поездки) — 50 рублей;\n",
#         "\n",
#         "с подпиской Ultra\n",
#         "* абонентская плата — 199 рублей в месяц;\n",
#         "* стоимость одной минуты поездки — 6 рублей;\n",
#         "* стоимость старта — бесплатно."

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Вот мой личный пример из 3 проекта:
#
# ![image.png](attachment:image.png)
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats as st
import seaborn as sns

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо. Модули выгружены

# %% [markdown]
# #### Шаг 1. Загрузка данных

# %%
try:
    users = pd.read_csv('users_go.csv')
    rides = pd.read_csv('rides_go.csv')
    subs = pd.read_csv('subscriptions_go.csv')
except: 
    users = pd.read_csv('/datasets/users_go.csv') 
    rides = pd.read_csv('/datasets/rides_go.csv') 
    subs = pd.read_csv('/datasets/subscriptions_go.csv')

# %% [markdown]
# Выгрузим первые 5 строк каждого датафрейма, затем данные о датафремайх, узнаем тип столбцев и проверим есть ли пропуски

# %%
users.head()
# Out:
#    user_id        name  age            city subscription_type
# 0        1        Кира   22          Тюмень             ultra
# 1        2   Станислав   31            Омск             ultra
# 2        3     Алексей   20          Москва             ultra
# 3        4  Константин   26  Ростов-на-Дону             ultra
# 4        5       Адель   28            Омск             ultra

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1565 non-null   int64
#  1   name               1565 non-null   object
#  2   age                1565 non-null   int64
#  3   city               1565 non-null   object
#  4   subscription_type  1565 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 61.3+ KB

# %% [markdown]
# В датафрейме данных о пользователях пропуски отсутствуют

# %%
rides.head()
# Out:
#    Unnamed: 0  user_id     distance   duration        date
# 0           0        1  4409.919140  25.599769  2021-01-01
# 1           1        1  2617.592153  15.816871  2021-01-18
# 2           2        1   754.159807   6.232113  2021-04-20
# 3           3        1  2694.783254  18.511000  2021-08-11
# 4           4        1  4028.687306  26.265803  2021-08-28

# %%
rides.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  18068 non-null  int64
#  1   user_id     18068 non-null  int64
#  2   distance    18068 non-null  float64
#  3   duration    18068 non-null  float64
#  4   date        18068 non-null  object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 705.9+ KB

# %% [markdown]
# В датафрейме поездов пропуски также отсутствуют

# %%
subs
# Out:
#    Unnamed: 0 subscription_type  minute_price  start_ride_price  \
# 0           0              free             8                50
# 1           1             ultra             6                 0
#
#    subscription_fee
# 0                 0
# 1               199

# %%
subs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2 non-null      int64
#  1   subscription_type  2 non-null      object
#  2   minute_price       2 non-null      int64
#  3   start_ride_price   2 non-null      int64
#  4   subscription_fee   2 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 208.0+ bytes

# %% [markdown]
# В файле subscriptions_go как мы видим есть только 2 строки, пользоветели с подпиской(ultra) и без нее(free)

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо бы как нибудь прокомментировать полученные данные в разделе
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
# __Комментарий от ревьюера №2__
#
# Отлично! Первый взгляд на данные есть

# %% [markdown]
# #### Шаг 2. Предобработка данных

# %% [markdown]
# * Переведем столбец date в подходящий для него формат.
# * Проверим есть ли прорущенные значения и дубликаты, если таковы имеются, то удалим их

# %%
sorted(rides['date'].unique())
# Out:
# ['2021-01-01',
#  '2021-01-02',
#  '2021-01-03',
#  '2021-01-04',
#  '2021-01-05',
#  '2021-01-06',
#  '2021-01-07',
#  '2021-01-08',
#  '2021-01-09',
#  '2021-01-10',
#  '2021-01-11',
#  '2021-01-12',
#  '2021-01-13',
#  '2021-01-14',
#  '2021-01-15',
#  '2021-01-16',
#  '2021-01-17',
#  '2021-01-18',
#  '2021-01-19',
#  '2021-01-20',
#  '2021-01-21',
#  '2021-01-22',
#  '2021-01-23',
#  '2021-01-24',
#  '2021-01-25',
#  '2021-01-26',
#  '2021-01-27',
#  '2021-01-28',
#  '2021-01-29',
#  '2021-01-30',
#  '2021-01-31',
#  '2021-02-01',
#  '2021-02-02',
#  '2021-02-03',
#  '2021-02-04',
#  '2021-02-05',
#  '2021-02-06',
#  '2021-02-07',
#  '2021-02-08',
#  '2021-02-09',
#  '2021-02-10',
#  '2021-02-11',
#  '2021-02-12',
#  '2021-02-13',
#  '2021-02-14',
#  '2021-02-15',
#  '2021-02-16',
#  '2021-02-17',
#  '2021-02-18',
#  '2021-02-19',
#  '2021-02-20',
#  '2021-02-21',
#  '2021-02-22',
#  '2021-02-23',
#  '2021-02-24',
#  '2021-02-25',
#  '2021-02-26',
#  '2021-02-27',
# ...

# %% [markdown]
# Как мы видим, данные датафрейма поездок содержать поездки от 1 января 2021 года до 30 декабря того же года.

# %%
rides['date'] = pd.to_datetime(rides['date'])

# %%
rides['month'] = pd.DatetimeIndex(rides['date']).month

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо бы проверить за какой период у нас данные. Проверить столбец длительности на предмет наличия аномалий. Например, если у нас разные года то январь 2021 и январь 2022 будут под одной цифрой (1).
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
# __Комментарий от ревьюера №2__
#
# Учтено

# %%
rides.isna().sum()
# Out:
# Unnamed: 0    0
# user_id       0
# distance      0
# duration      0
# date          0
# month         0
# dtype: int64

# %% [markdown]
# Пропуски в таблице rides отсутсвуют

# %%
users.isna().sum()
# Out:
# user_id              0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# dtype: int64

# %% [markdown]
# Пропуски в таблице users отсутсвуют

# %%
#узнаем, есть ли дубликаты в датафреймах
users.duplicated().sum()
# Out:
# 31

# %% [markdown]
# Дубликатов среди пользователей оказалось 31. Удалим их

# %%
users = users.drop_duplicates()

# %%
users.duplicated().sum()
# Out:
# 0

# %%
rides.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов среди поездок нет

# %% [markdown]
# ### Вывод:
#
# * мы удостоверились, что все данные о пездаках взяты за 2021 год
# * добавили новый столбец - месяц поездки. Например: январь - 1, фервраль - 2, и т.д
# * убедились в отсутсвии пропусков
# * проверили наличие дубликтов. Таких оказалось 31 и мы их удалили

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует вывод после раздела (можно описать качество исходных данных). Поправишь, этот момент в проекте?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Этот раздел сделан хорошо. Проверены основные возможные проблемы в данных.

# %% [markdown]
# #### Шаг 3. Исследовательский анализ данных

# %%
users['city'].value_counts()
# Out:
# Пятигорск         219
# Екатеринбург      204
# Ростов-на-Дону    198
# Краснодар         193
# Сочи              189
# Омск              183
# Тюмень            180
# Москва            168
# Name: city, dtype: int64

# %%
users['city'].value_counts(ascending=True).plot(kind='barh', figsize = (10,5), grid = True, 
                                                title='Частота встречаемости городов', ylabel='Город');

# %% [markdown]
# Как мы видим по визуализации, чаще всего встречается город Пятигорск, Москва же реже всего.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отличный и наглядный график 👍
#
# Здорово, когда он подписан. Так быстрее понять о чем идёт речь на нём.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует визуализация, одобавь, пожалуйста

# %%
subscription_counts = users['subscription_type'].value_counts()
total_users = subscription_counts.sum()
percentages = (subscription_counts / total_users) * 100

for subscription_type, percentage in percentages.items():
    print(f'Процент пользователей с подпиской {subscription_type}: {percentage:.2f}%')
# Out:
# Процент пользователей с подпиской free: 54.43%
# Процент пользователей с подпиской ultra: 45.57%

# %%
users['subscription_type'].value_counts().plot(kind='pie', 
                                               title='Cоотношение пользователей по подписке', 
                                               autopct='%0.2f%%');

# %% [markdown]
# Больше половины пользовтелей сервиса не являются обладателями платной подписки и они составляют почти 55% от общего числа, соответсвенно пользователи с подписками составляяют 45%

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Не посчитано соотношение категорий пользователей в процентах или в долях от целого, именно это просят в задании. Рекомендую использовать другой тип графика: круговую диаграмму, она лучше показывает соотношение частей целого.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
# Проверь, пожалуйста, по проекту, чтобы каждый чарт имел интерпретацию (вывод по нему)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Пользователей с подпиской немного меньше, тем не менее у компании-прокатчика есть неплохая база постоянных клиентов.

# %%
users['age'].plot(kind='hist', 
                  figsize=(8, 4), 
                  title='Возраст пользователей', 
                  bins=35, 
                  range=(10, 45)
                );
plt.xlabel('возраст');

plt.ylabel('количество пользователей');
users['age'].describe()
# Out:
# count    1534.000000
# mean       24.903520
# std         4.572367
# min        12.000000
# 25%        22.000000
# 50%        25.000000
# 75%        28.000000
# max        43.000000
# Name: age, dtype: float64

# %% [markdown]
# Как мы можем видеть по графику, наиболее часто встречаемый возраст составляет 25 лет.
#
# Также можем сделать вывод, что в основном клиентами сервиса яляются пользователи от 12 до 40 лет.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# График по данным  не оформлен до конца. Суть в том, что график должен быть наглядным без контекста (т.к. в реальной практике ты будешь показывать презентации или отчет сторонним людям).
#
# Тебе необходимо проследить чтобы всегда был заголовок и подписаны оси. Доработай этот момент пожалуйста.
#
# Данное замечания относится ко всему проекту и перепроверь его самостоятельно. Далее не буду акцентировать на этом внимание

# %%
rides['distance'].plot(kind='hist', 
                       bins=100, 
                       title='Расстояние поездки в метрах', 
                       xlabel = 'длинна поездки в мтерах',
                       ylabel = 'количество пользователей',
                       grid=True)
rides['distance'].describe()
# Out:
# count    18068.000000
# mean      3070.659976
# std       1116.831209
# min          0.855683
# 25%       2543.226360
# 50%       3133.609994
# 75%       3776.222735
# max       7211.007745
# Name: distance, dtype: float64

# %% [markdown]
# За одну поездку пользователи преодолевают от 1 до 7211 метров. Медиана всех значений равна 3134 метров

# %%
plt.boxplot(rides['distance']);

# %% [markdown]
# Большинство поездок составляет 3-3.5 километров. Есть выброс в диапазоне 500-600 метров
#
# Применив boxplot, мы узнали, что поездки короче 1000 метров и длинее 5500 считаются выбросами

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Лучше после каждого раздела, графика (или серии тестов) писать вывод по полученным данным с учетом поставленной бизнес задачи - так проще читать проект, поскольку будущим коллегам или заказчику не надо будет самим интерпретировать результаты каждого раздела, теста или графика.

# %%
rides['duration'].plot(kind='hist', 
                       bins=100, 
                       title='Продолжительность поездки в минутах', 
                       xlabel = 'продолжительность поездки в минутах',
                       ylabel = 'количество пользователей',
                       grid=True)

rides['duration'].describe()
# Out:
# count    18068.000000
# mean        17.805011
# std          6.091051
# min          0.500000
# 25%         13.597563
# 50%         17.678395
# 75%         21.724800
# max         40.823963
# Name: duration, dtype: float64

# %% [markdown]
# Продолжительность поездок распределена от 0 до 41 минуты. Продолжительность в 18 минут является как наиболее распространенной так и медианным значением. Значения в 1 минуты встречаются почти 100 раз и является выбросами в данном распределении

# %%
plt.boxplot(rides['duration']);

# %% [markdown]
# Средняя предолжительность большинства поездок около 17 минут. Есть небольшой выброс в районе 0-1 минуты. Можно предположить, что пользователи сразу завершали поездку после ее начала, возможно начав или отменив ее по ошибке.
#
# Использовав boxplot, выяснилось, что поездки короче 1 минуты дольше 35 минут считаются выбросами

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отличная реализация

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо бы графики подкрепить боксплотом

# %% [markdown]
# #### Шаг 4. Объединение данных

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#  Отсутствует проверка размерности:
#
# * размеры датасетов до объединения
# * размер результирующего датафрейма (с учетом типа объединения)

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1534 entries, 0 to 1533
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1534 non-null   int64
#  1   name               1534 non-null   object
#  2   age                1534 non-null   int64
#  3   city               1534 non-null   object
#  4   subscription_type  1534 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 71.9+ KB

# %% [markdown]
# Датафрем по пользователям содержит 1534 строки и 5 столбцев

# %%
rides.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  18068 non-null  int64
#  1   user_id     18068 non-null  int64
#  2   distance    18068 non-null  float64
#  3   duration    18068 non-null  float64
#  4   date        18068 non-null  datetime64[ns]
#  5   month       18068 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(3)
# memory usage: 847.1 KB

# %% [markdown]
# Датафрем по поездам содержит 18068 строки и 5 столбецев

# %%
data = users.merge(rides)
data = data.merge(subs, on='subscription_type')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18068 entries, 0 to 18067
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            18068 non-null  int64
#  1   name               18068 non-null  object
#  2   age                18068 non-null  int64
#  3   city               18068 non-null  object
#  4   subscription_type  18068 non-null  object
#  5   Unnamed: 0_x       18068 non-null  int64
#  6   distance           18068 non-null  float64
#  7   duration           18068 non-null  float64
#  8   date               18068 non-null  datetime64[ns]
#  9   month              18068 non-null  int64
#  10  Unnamed: 0_y       18068 non-null  int64
#  11  minute_price       18068 non-null  int64
#  12  start_ride_price   18068 non-null  int64
#  13  subscription_fee   18068 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(8), object(3)
# memory usage: 2.1+ MB

# %% [markdown]
# После объединения мы видим, что новый датафрейм содержит 18068 строк и 12 столбцев, то есть содержит в себе все данные 3-х отдельных датафреймов

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отлично. Проверка размерности датасетов проведена

# %%
data.head()
# Out:
#    user_id  name  age    city subscription_type  Unnamed: 0_x     distance  \
# 0        1  Кира   22  Тюмень             ultra             0  4409.919140
# 1        1  Кира   22  Тюмень             ultra             1  2617.592153
# 2        1  Кира   22  Тюмень             ultra             2   754.159807
# 3        1  Кира   22  Тюмень             ultra             3  2694.783254
# 4        1  Кира   22  Тюмень             ultra             4  4028.687306
#
#     duration       date  month  Unnamed: 0_y  minute_price  start_ride_price  \
# 0  25.599769 2021-01-01      1             1             6                 0
# 1  15.816871 2021-01-18      1             1             6                 0
# 2   6.232113 2021-04-20      4             1             6                 0
# 3  18.511000 2021-08-11      8             1             6                 0
# 4  26.265803 2021-08-28      8             1             6                 0
#
#    subscription_fee
# 0               199
# ...

# %% [markdown]
# Создадим 2 датафрейма - один с подпиской, другой без подписки

# %%
ultra = data.loc[data['subscription_type'] == 'ultra']

ultra.head()
# Out:
#    user_id  name  age    city subscription_type  Unnamed: 0_x     distance  \
# 0        1  Кира   22  Тюмень             ultra             0  4409.919140
# 1        1  Кира   22  Тюмень             ultra             1  2617.592153
# 2        1  Кира   22  Тюмень             ultra             2   754.159807
# 3        1  Кира   22  Тюмень             ultra             3  2694.783254
# 4        1  Кира   22  Тюмень             ultra             4  4028.687306
#
#     duration       date  month  Unnamed: 0_y  minute_price  start_ride_price  \
# 0  25.599769 2021-01-01      1             1             6                 0
# 1  15.816871 2021-01-18      1             1             6                 0
# 2   6.232113 2021-04-20      4             1             6                 0
# 3  18.511000 2021-08-11      8             1             6                 0
# 4  26.265803 2021-08-28      8             1             6                 0
#
#    subscription_fee
# 0               199
# ...

# %%
free = data.loc[data['subscription_type'] == 'free']

free.head()
# Out:
#       user_id   name  age  city subscription_type  Unnamed: 0_x     distance  \
# 6500      700  Айдар   22  Омск              free          6500  2515.690719
# 6501      700  Айдар   22  Омск              free          6501   846.932642
# 6502      700  Айдар   22  Омск              free          6502  4004.434142
# 6503      700  Айдар   22  Омск              free          6503  1205.911290
# 6504      700  Айдар   22  Омск              free          6504  3047.379435
#
#        duration       date  month  Unnamed: 0_y  minute_price  \
# 6500  14.944286 2021-01-02      1             0             8
# 6501  16.234663 2021-02-01      2             0             8
# 6502  20.016628 2021-02-04      2             0             8
# 6503   9.782872 2021-02-10      2             0             8
# 6504  17.427673 2021-02-14      2             0             8
#
#       start_ride_price  subscription_fee
# 6500                50                 0
# 6501                50                 0
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Целесообразно вывести несколько строк из общего и отдельных датафреймов.

# %%
ax = free['distance'].plot(kind='hist', 
                            bins=100, 
                            title='Cравнение подписок', 
                            grid=True,
                            legend=True,
                            label='без подписки',
                          );

ultra['distance'].plot(kind='hist', 
                      bins=100, 
                      grid=True, 
                      legend=True,
                      label='с подпиской',
                      ylabel='Количество поездок',
                      xlabel='Расстояние поездки в метрах',
                      ax=ax);

# %% [markdown]
# Из графика мы видим, что пользователи с подпиской реже совершают длинные поздеки, чем пользователии без нее.
#
# Пользователеи без подписок чаще ездят большее расстояние

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Аналогично, отсутствует интерпретация полученных данных

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# У пользователей без подписки значительно больше коротких поездок - до 1 км и в целом максимальная дальность поездки выше, чем у платных пользователей.

# %%
ax = free['duration'].plot(kind='hist', 
                            bins=35, 
                            title='Cравнение подписок', 
                            grid=True,
                            legend=True,
                            label='без подписки',
                          );

ultra['duration'].plot(kind='hist', 
                      bins=35, 
                      grid=True, 
                      legend=True,
                      label='с подпиской',
                      ylabel='Количество поездок',
                      xlabel='Продолжительность поездки в минутах',
                      ax=ax);

# %% [markdown]
# Из графика мы видим, что пользователи с подпиской реже совершают долгие поздеки, чем пользователии без нее.
#
# Пользователеи без подписки ездят дольше и чаще

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# В целом картина такая же - распределение внутри категорий имеют одинаковый профиль (и одинаковый с профилем распределения до разбивки на категории - строили на ранних этапах), но в каждом из диапазонов бесплатных пользователей чуть больше, но их, как мы помним, и в целом больше.
#
# Краевые значения (минимум и максимум) у бесплатных пользователей смещены влево относительно платных подписчиков - стоимость минуты все-таки больше, значит часть пользователей торопится завершить поездки за меньший срок. Но при этом визуально среднее значение не сильно смещено

# %% [markdown]
# #### Шаг 5. Подсчёт выручки

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Нет проверки на пропуски в сводной таблице перед расчетом выручки

# %%
data['duration'] = np.ceil(data['duration']) 

data.head()
# Out:
#    user_id  name  age    city subscription_type  Unnamed: 0_x     distance  \
# 0        1  Кира   22  Тюмень             ultra             0  4409.919140
# 1        1  Кира   22  Тюмень             ultra             1  2617.592153
# 2        1  Кира   22  Тюмень             ultra             2   754.159807
# 3        1  Кира   22  Тюмень             ultra             3  2694.783254
# 4        1  Кира   22  Тюмень             ultra             4  4028.687306
#
#    duration       date  month  Unnamed: 0_y  minute_price  start_ride_price  \
# 0      26.0 2021-01-01      1             1             6                 0
# 1      16.0 2021-01-18      1             1             6                 0
# 2       7.0 2021-04-20      4             1             6                 0
# 3      19.0 2021-08-11      8             1             6                 0
# 4      27.0 2021-08-28      8             1             6                 0
#
#    subscription_fee
# 0               199
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отлично, что используешь именно np.ceil(). Грамотный шаг

# %%
data_grouped = data.groupby(['user_id', 'month', 'subscription_type']).agg({'distance': ['sum', 'count'], 'duration': 'sum'}).reset_index()

# %%
data_grouped.columns = ['user_id', 'месяц', 'тип подписки', 'суммарное расстояние', 'кол-во поездок', 'суммарная длительность']

# %%
data_grouped['income'] = (data['start_ride_price'] * data_grouped['кол-во поездок']) + (data['minute_price'] * data_grouped['суммарная длительность']) + data['subscription_fee']

# %%
data_grouped
# Out:
#        user_id  месяц тип подписки  суммарное расстояние  кол-во поездок  \
# 0            1      1        ultra           7027.511294               2
# 1            1      4        ultra            754.159807               1
# 2            1      8        ultra           6723.470560               2
# 3            1     10        ultra           5809.911100               2
# 4            1     11        ultra           7003.499363               3
# ...        ...    ...          ...                   ...             ...
# 11326     1534      6         free           3409.468534               2
# 11327     1534      8         free           7622.453034               2
# 11328     1534      9         free           4928.173852               1
# 11329     1534     11         free          13350.015305               4
# 11330     1534     12         free           2371.711192               1
#
#        суммарная длительность  income
# 0                        42.0   451.0
# ...

# %%
#проверим имеются ли пропуски
data_grouped.isna().sum()
# Out:
# user_id                   0
# месяц                     0
# тип подписки              0
# суммарное расстояние      0
# кол-во поездок            0
# суммарная длительность    0
# income                    0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Корректная реализация. Молодец)

# %% [markdown]
# #### Шаг 6. Проверка гипотез

# %% [markdown]
# 6.1 Важно понять, тратят ли пользователи с подпиской больше времени на поездки? Если да, то пользователи с подпиской могут быть «выгоднее» для компании. Проверьте гипотезу. Используйте исходные данные о продолжительности каждой сессии — отдельно для подписчиков и тех, у кого нет подписки.
#
# * Нулевая гипотеза: среднее время поездок пользователей с подпиской и пользователей без подписки равны
# * Альтернативная гипотеза: пользователи с подпиской тратят больше времени

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Верная интерпретация нулевой и альтернативной гипотез
# </div>

# %%
alpha = 0.05

results = st.ttest_ind(ultra['duration'], free['duration'], alternative='greater')

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 1.2804098316645618e-34
# Отвергаем нулевую гипотезу

# %% [markdown]
# 6.2 Расстояние одной поездки в 3130 метров — оптимальное с точки зрения износа самоката. Можно ли сказать, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров? Проверьте гипотезу и сделайте выводы.
#
# * Нулевая гипотеза: среднее расстояние поездки пользователей с подпиской равно 3130 метрам
# * Альтернативная гипотеза: среднее расстояние поездки пользователи с подпиской > 3130 метров

# %%
alpha = 0.05

results = st.ttest_1samp(ultra['distance'], 3130, alternative='greater')

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.9195368847849785
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Исходя из теста мы не можем сказать, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, превышает 3130 метров

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Смотри, поскольку оптимальное расстояние по износу составляет 3130 м, значит большее расстояние приводит к повышенному износу самоката. Следовательно имеет смысл проверить одностороннюю гипотезу, что расстояние, которое проезжают пользователи с подпиской не превышает оптимального расстояния в 3130 м.
#
# То есть в статистическом тесте стоит поставить параметр alternative = 'greater' и изменить Н1 на знак `больше`

# %% [markdown]
# 6.3 Проверьте гипотезу о том, будет ли помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки. Сделайте вывод.
#
# * Нулевая гипотеза: месячная выручка от пользователей с подпиской и без нее равны.
# * Альтернативная гипотеза: месячная выручка от пользователей с подпиской больше, чем выручка от пользователей без нее

# %%
ultra_income = data_grouped[data_grouped['тип подписки'] == 'ultra'] 
free_income = data_grouped[data_grouped['тип подписки'] == 'free'] 

alpha = 0.05

results = st.ttest_ind(ultra_income['income'], free_income['income'], alternative='greater')

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 1.822773456181981e-12
# Отвергаем нулевую гипотезу

# %% [markdown]
# Значение p-value меньше 0.05 - нулевая гипотеза отвергается. Значит, выручка от пользователей с подпиской больше, чем без нее

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Методологически проверка гипотез проведена верно и наглядный вывод результатов

# %% [markdown]
# 6.4 Представьте такую ситуацию: техническая команда сервиса обновила сервера, с которыми взаимодействует мобильное приложение. Она надеется, что из-за этого количество обращений в техподдержку значимо снизилось. Некоторый файл содержит для каждого пользователя данные о количестве обращений до обновления и после него. Какой тест вам понадобился бы для проверки этой гипотезы?

# %% [markdown]
# Для проверки такой гипотезы нам понадобится "Двухвыборочный t-тест для зависимых выборок", так как он подходит для проверки двух зависимых друг от друга выборок.
# Чтобы проверить гипотезу о равенстве среднего генеральной совокупности для зависимых (парных) выборок в Python, применим метод scipy.stats.ttest_rel().

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Для решения потребуется тест на равенство средних для зависимых выборок, до и после изменений.>

# %% [markdown]
# #### Шаг 7. Распределения

# %% [markdown]
# <div class="alert alert-info">Обязательно хочу сделать и этот шаг, но не успеваю, к сожалению. На носу новая неделя - новый спринт, но я обязательно вернусь к этому заданию</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Договорились)

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Итоговый вывод завершает твое исследование. А его нету...В идеале добавить рекомендации бизнесу
# </div>

# %% [markdown]
# ### Вывод
#
# Все исходные данные во всех файлах не содержали пропусков, значительных выбросов, а также дубликатов, кроме тех, которые были обнаружены в файле ‘users_go.csv’. При копировании данных из файлов в датафреймы, данные столбцов были не в оптимальном состоянии. В ходе предобработки данных они были оптимизированы для целей данного проекта.
#
# * пользователей с подпиской «free» всего 835, что составляет 54.43% от общего количества и на 136 больше, чем с подпиской «ultra».
# * по предоставленным данным из 8-ми городов, больше всего пользователей из Пятигорска (219 поездок), меньше всего из Москвы (168 поездок)
# * средний возраст пользователя сервиса - 25 лет
# * среднее расстояние большинства поездок чуль больше 3-х км
# * Продолжительность поездок от 0 до 41 минуты. Чаще всего встречаются поездки длинтельность 18 минут
# * пользователей без подписки больше чем пользователей с подпиской
# * пользователи без подписки ездят больше, чаще и дольше
#
# __В ходе исследования были подтверждены следующие гипотезы:__
#
# * пользователи с подпиской тратят больше времени
# * средняя дистанция поездки пользователи с подпиской меньше 3130 метров (оптимальное расстояние с точки зрения износа самоката)
# * месячная выручка от пользователей с подпиской больше, чем выручка от пользователей без нее

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Вводная часть
#
# 2) Поистроение и оформление графиков
#
# 3) Проверка  датафреймов до/после работы с ними
#
# 4) Финальный вывод
#
# 5) После каждого раздела / графика (или серии тестов) писать вывод по полученным данным с учетом поставленной бизнес задачи
#
# 6) Подправить выводы, после изменений
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №2__
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличный метариал по статистике.
#
# * Курс "Вероятность и статистика" | Глеб Михайлов (free): https://www.youtube.com/playlist?list=PLQJ7ptkRY-xbHLLI66KdscKp_FJt0FsIi
#
# * Методы обнаружения выбросов: https://youtu.be/TOK7Kq7x0yc
#
#
# </div>
